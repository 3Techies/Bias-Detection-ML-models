# %% [markdown]
# <a href="https://colab.research.google.com/github/3Techies/Bias-Detection-ML-models/blob/mohittypeshi/notebooks/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is the test text for connecting Google Colab to GitHub

# %%
# some changes are made in the notebook
