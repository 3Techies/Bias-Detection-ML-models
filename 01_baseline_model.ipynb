# %% [markdown]
# <a href="https://colab.research.google.com/github/3Techies/Bias-Detection-ML-models/blob/main/01_baseline_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hi how are you

# %%
#mohit madaltod
